# %%
from part2_house_value_regression import Regressor, save_regressor
from pandas import read_csv

def train_regressor(model, model_name, hidden_count: int, nb_epochs=100, learning_rate=0.01):
    output_label = "median_house_value"

    # Use pandas to read CSV data as it contains various object types
    # Feel free to use another CSV reader tool
    # But remember that LabTS tests take Pandas DataFrame as inputs
    data = read_csv("housing.csv")

    # Splitting input and output
    x_train = data.loc[:, data.columns != output_label]
    y_train = data.loc[:, [output_label]]

    eval_data = read_csv("housing_eval.csv")
    x_eval = eval_data.loc[:, eval_data.columns != output_label]
    y_eval = eval_data.loc[:, [output_label]]

    # Training
    # This example trains on the whole available dataset.
    # You probably want to separate some held-out data
    # to make sure the model isn't overfitting
    regressor = Regressor(x_train, model=model, nb_epoch=nb_epochs, batch_size=32, learning_rate=learning_rate)
    regressor.hidden_count = hidden_count
    regressor.fit(x_train, y_train, x_eval=x_eval, y_eval=y_eval)

    # Error
    error = regressor.score(x_train, y_train)
    print("\nRegressor error: {}\n".format(error))

    save_regressor(regressor, model_name)

    return regressor, model_name

# %%
from pandas import DataFrame
from math import log10
from pathlib import Path

def dump_history(regressor: Regressor, model_name: str):
    history_train = regressor.loss_history()
    history_eval = regressor.loss_history_eval()

    history_out_path = Path(f'assets/{model_name}-lr-{int(-log10(regressor.learning_rate))}-epch-{regressor.nb_epoch}.csv')  
    history_out_path.parent.mkdir(parents=True, exist_ok=True) 

    history = DataFrame(data={'train': history_train, 'eval': history_eval})
    history.to_csv(history_out_path)

# %%
from matplotlib.pyplot import figure, plot

def get_eval_all_fig_name(count: int, lr: float):
    return f'eval-hyperparam-search-{count}-lr-1e-{int(-log10(lr))}'

def output_eval_all_fig(count: int, lr: float, output_fs: bool = False, output_ui: bool = False):
    fig_eval_all = figure(get_eval_all_fig_name(count, lr))
    fig_eval_all.legend()

    if output_ui: fig_eval_all.show()
    if output_fs: fig_eval_all.savefig(f'assets/eval-hyperparam-search-{count}-lr-1e-{int(-log10(lr))}.png')

def display_loss_history(regressor: Regressor, model_name: str):
    loss_history = regressor.loss_history()
    loss_history_eval = regressor.loss_history_eval()

    fig = figure()
    plot(loss_history, label='training')
    plot(loss_history_eval, label='eval')
    fig.show()
    fig.savefig(f'assets/{model_name}-lr-{int(-log10(regressor.learning_rate))}-epch-{regressor.nb_epoch}.png')

    figure(get_eval_all_fig_name(regressor.hidden_count, regressor.learning_rate))
    plot(loss_history_eval, label=f'{model_name}-lr-{int(-log10(regressor.learning_rate))}-epch-{regressor.nb_epoch}')
    output_eval_all_fig(regressor.hidden_count, regressor.learning_rate, output_fs=True)

# %%
from multiprocessing import Pool
from torch.nn import Module, Sequential, Linear, ReLU, SiLU

def output(regressor: Regressor, model_name: str):
    dump_history(regressor, model_name)
    display_loss_history(regressor, model_name)

def hyperparam_search(count: int, size: int, activation_func: Module, lr: float, name: str):
    layers = \
        [Linear(13, size), activation_func()] + \
        [Linear(size, size), activation_func()] * count + \
        [Linear(size, 1)]

    output(*train_regressor(
        Sequential(*layers),
        model_name=name,
        hidden_count=count,
        nb_epochs=100,
        learning_rate=lr,
    ))

    print(f'Completed {name}!')

for count in range(1, 5):
    for size in [5, 10, 50, 100, 200, 500]:
        for lr in [0.001, 0.0001, 0.00001]:
            hyperparam_search(count, size, ReLU, lr, f'relu-{count}-{size}')
            # hyperparam_search(count, size, SiLU, lr, f'silu-{count}-{size}')
# Out:
# Epoch 0 error (train): 104647.8359375
# Epoch 0 error (eval): 103274.4609375
# Epoch 1 error (train): 72731.8125
# Epoch 1 error (eval): 72344.7109375
# Epoch 2 error (train): 67622.40625
# Epoch 2 error (eval): 67492.890625
# Epoch 3 error (train): 65958.375
# Epoch 3 error (eval): 66039.0546875
# Epoch 4 error (train): 64976.59765625
# Epoch 4 error (eval): 65082.7890625
# Epoch 5 error (train): 64224.6875
# Epoch 5 error (eval): 64548.5703125
# Epoch 6 error (train): 63661.5546875
# Epoch 6 error (eval): 64122.27734375
# Epoch 7 error (train): 63441.84375
# Epoch 7 error (eval): 64005.71484375
# Epoch 8 error (train): 62760.38671875
# Epoch 8 error (eval): 63417.125
# Epoch 9 error (train): 62461.25
# Epoch 9 error (eval): 63142.98046875
# Epoch 10 error (train): 62284.328125
# Epoch 10 error (eval): 62959.12109375
# Epoch 11 error (train): 61840.453125
# Epoch 11 error (eval): 62725.01171875
# Epoch 12 error (train): 61347.6875
# Epoch 12 error (eval): 62275.22265625
# Epoch 13 error (train): 61095.64453125
# Epoch 13 error (eval): 62037.28515625
# Epoch 14 error (train): 60502.76171875
# Epoch 14 error (eval): 61426.98046875
# Epoch 15 error (train): 60420.31640625
# Epoch 15 error (eval): 61488.60546875
# Epoch 16 error (train): 60048.5625
# Epoch 16 error (eval): 61021.30859375
# Epoch 17 error (train): 59960.75390625
# Epoch 17 error (eval): 61080.890625
# Epoch 18 error (train): 59628.7109375
# Epoch 18 error (eval): 60733.84375
# Epoch 19 error (train): 59625.05859375
# Epoch 19 error (eval): 60679.9765625
# Epoch 20 error (train): 59630.2421875
# Epoch 20 error (eval): 60796.98046875
# Epoch 21 error (train): 59167.78515625
# Epoch 21 error (eval): 60307.3515625
# Epoch 22 error (train): 59389.921875
# Epoch 22 error (eval): 60678.17578125
# Epoch 23 error (train): 59184.76953125
# Epoch 23 error (eval): 60454.03125
# Epoch 24 error (train): 58940.18359375
# Epoch 24 error (eval): 60178.43359375
# Epoch 25 error (train): 59035.5390625
# Epoch 25 error (eval): 60153.28125
# Epoch 26 error (train): 58895.9296875
# Epoch 26 error (eval): 60142.03125
# Epoch 27 error (train): 59379.12109375
# Epoch 27 error (eval): 60533.51953125
# Epoch 28 error (train): 58784.67578125
# Epoch 28 error (eval): 60004.5
# Epoch 29 error (train): 58653.03515625
# Epoch 29 error (eval): 59960.984375
# Epoch 30 error (train): 58802.5859375
# Epoch 30 error (eval): 60036.0859375
# Epoch 31 error (train): 58625.32421875
# Epoch 31 error (eval): 59960.62109375
# Epoch 32 error (train): 58666.09765625
# Epoch 32 error (eval): 59880.6015625
# Epoch 33 error (train): 58709.15234375
# Epoch 33 error (eval): 59909.73046875
# Epoch 34 error (train): 58489.359375
# Epoch 34 error (eval): 59861.98828125
# Epoch 35 error (train): 58421.91015625
# Epoch 35 error (eval): 59732.69140625
# Epoch 36 error (train): 58723.35546875
# Epoch 36 error (eval): 60057.75390625
# Epoch 37 error (train): 58465.421875
# Epoch 37 error (eval): 59959.36328125
# Epoch 38 error (train): 58321.3984375
# Epoch 38 error (eval): 59678.84765625
# Epoch 39 error (train): 58557.0078125
# Epoch 39 error (eval): 59883.83203125
# Epoch 40 error (train): 58635.87109375
# Epoch 40 error (eval): 59891.859375
# Epoch 41 error (train): 58336.3828125
# Epoch 41 error (eval): 59808.30859375
# Epoch 42 error (train): 58344.22265625
# Epoch 42 error (eval): 59791.51953125
# Epoch 43 error (train): 58294.6875
# Epoch 43 error (eval): 59715.41796875
# Epoch 44 error (train): 58527.2734375
# Epoch 44 error (eval): 59951.41015625
# Epoch 45 error (train): 58209.63671875
# Epoch 45 error (eval): 59661.421875
# Epoch 46 error (train): 58222.44921875
# Epoch 46 error (eval): 59797.3984375
# Epoch 47 error (train): 58180.18359375
# Epoch 47 error (eval): 59583.0390625
# Epoch 48 error (train): 58200.015625
# Epoch 48 error (eval): 59671.96484375
# Epoch 49 error (train): 58175.00390625
# Epoch 49 error (eval): 59616.56640625
# Epoch 50 error (train): 58096.59375
# Epoch 50 error (eval): 59589.296875
# Epoch 51 error (train): 58180.55078125
# Epoch 51 error (eval): 59664.2890625
# Epoch 52 error (train): 58071.03515625
# Epoch 52 error (eval): 59551.1875
# Epoch 53 error (train): 58285.01953125
# Epoch 53 error (eval): 59860.33203125
# Epoch 54 error (train): 58377.5
# Epoch 54 error (eval): 60042.2890625
# Epoch 55 error (train): 58086.33203125
# Epoch 55 error (eval): 59358.8046875
# Epoch 56 error (train): 57953.43359375
# Epoch 56 error (eval): 59419.49609375
# Epoch 57 error (train): 58088.21484375
# Epoch 57 error (eval): 59423.3359375
# Epoch 58 error (train): 58070.0703125
# Epoch 58 error (eval): 59378.3359375
# Epoch 59 error (train): 57960.0546875
# Epoch 59 error (eval): 59331.328125
# Epoch 60 error (train): 57885.203125
# Epoch 60 error (eval): 59436.78515625
# Epoch 61 error (train): 58009.328125
# Epoch 61 error (eval): 59648.48046875
# Epoch 62 error (train): 57802.82421875
# Epoch 62 error (eval): 59293.26171875
# Epoch 63 error (train): 57875.3515625
# Epoch 63 error (eval): 59319.28125
# Epoch 64 error (train): 57849.671875
# Epoch 64 error (eval): 59230.8046875
# Epoch 65 error (train): 57886.4609375
# Epoch 65 error (eval): 59202.67578125
# Epoch 66 error (train): 57983.27734375
# Epoch 66 error (eval): 59408.4765625
# Epoch 67 error (train): 57770.78515625
# Epoch 67 error (eval): 59158.0390625
# Epoch 68 error (train): 57789.859375
# Epoch 68 error (eval): 59428.3515625
# Epoch 69 error (train): 58242.60546875
# Epoch 69 error (eval): 59581.88671875
# Epoch 70 error (train): 57687.43359375
# Epoch 70 error (eval): 59207.83203125
# Epoch 71 error (train): 57710.8515625
# Epoch 71 error (eval): 59194.39453125
# Epoch 72 error (train): 57794.5703125
# Epoch 72 error (eval): 59047.91796875
# Epoch 73 error (train): 57654.609375
# Epoch 73 error (eval): 59201.23046875
# Epoch 74 error (train): 57561.59765625
# Epoch 74 error (eval): 59055.82421875
# Epoch 75 error (train): 57651.22265625
# Epoch 75 error (eval): 59130.92578125
# Epoch 76 error (train): 57691.9375
# Epoch 76 error (eval): 59268.42578125
# Epoch 77 error (train): 57620.88671875
# Epoch 77 error (eval): 59142.69140625
# Epoch 78 error (train): 57546.9375
# Epoch 78 error (eval): 59052.984375
# Epoch 79 error (train): 57447.8515625
# Epoch 79 error (eval): 58979.1953125
# Epoch 80 error (train): 57505.0859375
# Epoch 80 error (eval): 58973.6875
# Epoch 81 error (train): 57479.68359375
# Epoch 81 error (eval): 59201.30859375
# Epoch 82 error (train): 57530.87890625
# Epoch 82 error (eval): 59070.55859375
# Epoch 83 error (train): 57495.875
# Epoch 83 error (eval): 58905.91796875
# Epoch 84 error (train): 57390.78125
# Epoch 84 error (eval): 58818.05078125
# Epoch 85 error (train): 57390.2265625
# Epoch 85 error (eval): 58848.5234375
# Epoch 86 error (train): 57563.8203125
# Epoch 86 error (eval): 59140.83203125
# Epoch 87 error (train): 57469.93359375
# Epoch 87 error (eval): 58766.8046875
# Epoch 88 error (train): 57602.51953125
# Epoch 88 error (eval): 58873.80859375
# Epoch 89 error (train): 57308.734375
# Epoch 89 error (eval): 58729.54296875
# Epoch 90 error (train): 57442.55078125
# Epoch 90 error (eval): 58860.42578125
# Epoch 91 error (train): 57705.1484375
# Epoch 91 error (eval): 59199.36328125
# Epoch 92 error (train): 57498.27734375
# Epoch 92 error (eval): 59012.89453125
# Epoch 93 error (train): 57305.88671875
# Epoch 93 error (eval): 58820.578125
# Epoch 94 error (train): 57252.47265625
# Epoch 94 error (eval): 58873.98046875
# Epoch 95 error (train): 57406.44921875
# Epoch 95 error (eval): 58813.47265625
# Epoch 96 error (train): 57451.03515625
# Epoch 96 error (eval): 59007.95703125
# Epoch 97 error (train): 57494.02734375
# Epoch 97 error (eval): 58933.41796875
# Epoch 98 error (train): 57445.51171875
# Epoch 98 error (eval): 58959.44921875
# Epoch 99 error (train): 57957.07421875
# Epoch 99 error (eval): 59268.89453125
#
# Regressor error: 57957.07421875
#
#
# Saved model in assets/relu-1-5-lr-0.001-epch-100.pickle
#
# Completed relu-1-5!
# Epoch 0 error (train): 115616.125
# Epoch 0 error (eval): 114392.703125
# Epoch 1 error (train): 115167.0390625
# Epoch 1 error (eval): 113954.5703125
# Epoch 2 error (train): 114829.9140625
# Epoch 2 error (eval): 113623.921875
# Epoch 3 error (train): 114408.7265625
# Epoch 3 error (eval): 113198.46875
# Epoch 4 error (train): 113817.3359375
# Epoch 4 error (eval): 112592.0546875
# Epoch 5 error (train): 112891.8359375
# Epoch 5 error (eval): 111642.8828125
# Epoch 6 error (train): 111272.203125
# Epoch 6 error (eval): 110004.8125
# Epoch 7 error (train): 107894.71875
# Epoch 7 error (eval): 106691.140625
# Epoch 8 error (train): 101081.9140625
# Epoch 8 error (eval): 99992.03125
# Epoch 9 error (train): 89185.7578125
# Epoch 9 error (eval): 88225.984375
# Epoch 10 error (train): 77252.890625
# Epoch 10 error (eval): 76463.1953125
# Epoch 11 error (train): 72230.078125
# Epoch 11 error (eval): 71467.96875
# Epoch 12 error (train): 70659.796875
# Epoch 12 error (eval): 69911.109375
# Epoch 13 error (train): 69717.125
# Epoch 13 error (eval): 69038.625
# Epoch 14 error (train): 68988.1328125
# Epoch 14 error (eval): 68340.1875
# Epoch 15 error (train): 68381.953125
# Epoch 15 error (eval): 67720.9140625
# Epoch 16 error (train): 67854.6171875
# Epoch 16 error (eval): 67264.796875
# Epoch 17 error (train): 67400.4609375
# Epoch 17 error (eval): 66807.40625
# Epoch 18 error (train): 67006.4453125
# Epoch 18 error (eval): 66484.7734375
# Epoch 19 error (train): 66670.3125
# Epoch 19 error (eval): 66130.265625
# Epoch 20 error (train): 66373.8828125
# Epoch 20 error (eval): 65882.171875
# Epoch 21 error (train): 66122.1640625
# Epoch 21 error (eval): 65662.1015625
# Epoch 22 error (train): 65886.390625
# Epoch 22 error (eval): 65398.48828125
# Epoch 23 error (train): 65693.625
# Epoch 23 error (eval): 65238.75
# Epoch 24 error (train): 65536.390625
# Epoch 24 error (eval): 65138.1875
# Epoch 25 error (train): 65364.171875
# Epoch 25 error (eval): 64911.19140625
# Epoch 26 error (train): 65229.62109375
# Epoch 26 error (eval): 64810.60546875
# Epoch 27 error (train): 65108.5625
# Epoch 27 error (eval): 64698.2421875
# Epoch 28 error (train): 65005.4296875
# Epoch 28 error (eval): 64620.87890625
# Epoch 29 error (train): 64904.26171875
# Epoch 29 error (eval): 64482.05859375
# Epoch 30 error (train): 64808.27734375
# Epoch 30 error (eval): 64421.19921875
# Epoch 31 error (train): 64720.4453125
# Epoch 31 error (eval): 64301.28515625
# Epoch 32 error (train): 64624.28515625
# Epoch 32 error (eval): 64208.515625
# Epoch 33 error (train): 64547.43359375
# Epoch 33 error (eval): 64190.62109375
# Epoch 34 error (train): 64461.9140625
# Epoch 34 error (eval): 64104.4765625
# Epoch 35 error (train): 64407.46875
# Epoch 35 error (eval): 64044.9609375
# Epoch 36 error (train): 64302.08203125
# Epoch 36 error (eval): 63935.18359375
# Epoch 37 error (train): 64226.5625
# Epoch 37 error (eval): 63878.8984375
# Epoch 38 error (train): 64149.8515625
# Epoch 38 error (eval): 63828.8671875
# Epoch 39 error (train): 64082.2421875
# Epoch 39 error (eval): 63745.05078125
# Epoch 40 error (train): 64013.109375
# Epoch 40 error (eval): 63716.86328125
# Epoch 41 error (train): 63948.32421875
# Epoch 41 error (eval): 63674.4453125
# Epoch 42 error (train): 63878.2578125
# Epoch 42 error (eval): 63559.97265625
# Epoch 43 error (train): 63841.06640625
# Epoch 43 error (eval): 63533.19140625
# Epoch 44 error (train): 63750.36328125
# Epoch 44 error (eval): 63441.71875
# Epoch 45 error (train): 63702.140625
# Epoch 45 error (eval): 63430.52734375
# Epoch 46 error (train): 63625.47265625
# Epoch 46 error (eval): 63326.30078125
# Epoch 47 error (train): 63584.48828125
# Epoch 47 error (eval): 63346.5234375
# Epoch 48 error (train): 63553.9453125
# Epoch 48 error (eval): 63315.51171875
# Epoch 49 error (train): 63462.015625
# Epoch 49 error (eval): 63249.05859375
# Epoch 50 error (train): 63426.859375
# Epoch 50 error (eval): 63188.00390625
# Epoch 51 error (train): 63355.03515625
# Epoch 51 error (eval): 63120.9140625
# Epoch 52 error (train): 63297.92578125
# Epoch 52 error (eval): 63109.64453125
# Epoch 53 error (train): 63259.140625
# Epoch 53 error (eval): 63090.44140625
# Epoch 54 error (train): 63201.3671875
# Epoch 54 error (eval): 63029.94921875
# Epoch 55 error (train): 63163.51171875
# Epoch 55 error (eval): 63011.8984375
# Epoch 56 error (train): 63106.01171875
# Epoch 56 error (eval): 62969.8125
# Epoch 57 error (train): 63058.34765625
# Epoch 57 error (eval): 62938.86328125
# Epoch 58 error (train): 63005.47265625
# Epoch 58 error (eval): 62900.62890625
# Epoch 59 error (train): 62954.37109375
# Epoch 59 error (eval): 62851.10546875
# Epoch 60 error (train): 62907.53125
# Epoch 60 error (eval): 62818.68359375
# Epoch 61 error (train): 62860.5234375
# Epoch 61 error (eval): 62808.44921875
# Epoch 62 error (train): 62816.0078125
# Epoch 62 error (eval): 62759.6328125
# Epoch 63 error (train): 62778.07421875
# Epoch 63 error (eval): 62731.4453125
# Epoch 64 error (train): 62755.46484375
# Epoch 64 error (eval): 62757.98046875
# Epoch 65 error (train): 62704.8671875
# Epoch 65 error (eval): 62709.84375
# Epoch 66 error (train): 62675.37109375
# Epoch 66 error (eval): 62648.1953125
# Epoch 67 error (train): 62640.0546875
# Epoch 67 error (eval): 62628.03515625
# Epoch 68 error (train): 62583.3984375
# Epoch 68 error (eval): 62624.46875
# Epoch 69 error (train): 62557.69921875
# Epoch 69 error (eval): 62560.0625
# Epoch 70 error (train): 62520.41796875
# Epoch 70 error (eval): 62563.8671875
# Epoch 71 error (train): 62482.4453125
# Epoch 71 error (eval): 62541.0625
# Epoch 72 error (train): 62447.58203125
# Epoch 72 error (eval): 62556.85546875
# Epoch 73 error (train): 62412.9921875
# Epoch 73 error (eval): 62508.74609375
# Epoch 74 error (train): 62385.98046875
# Epoch 74 error (eval): 62476.6953125
# Epoch 75 error (train): 62369.609375
# Epoch 75 error (eval): 62488.7421875
# Epoch 76 error (train): 62326.40234375
# Epoch 76 error (eval): 62439.46484375
# Epoch 77 error (train): 62295.0859375
# Epoch 77 error (eval): 62445.0
# Epoch 78 error (train): 62255.3671875
# Epoch 78 error (eval): 62411.46875
# Epoch 79 error (train): 62254.46484375
# Epoch 79 error (eval): 62410.1953125
# Epoch 80 error (train): 62212.75390625
# Epoch 80 error (eval): 62400.91015625
# Epoch 81 error (train): 62196.3515625
# Epoch 81 error (eval): 62418.8359375
# Epoch 82 error (train): 62181.05859375
# Epoch 82 error (eval): 62384.6640625
# Epoch 83 error (train): 62116.69921875
# Epoch 83 error (eval): 62309.16796875
# Epoch 84 error (train): 62086.7421875
# Epoch 84 error (eval): 62316.546875
# Epoch 85 error (train): 62058.765625
# Epoch 85 error (eval): 62300.42578125
# Epoch 86 error (train): 62044.40625
# Epoch 86 error (eval): 62300.41015625
# Epoch 87 error (train): 62023.3359375
# Epoch 87 error (eval): 62313.76953125
# Epoch 88 error (train): 61983.5703125
# Epoch 88 error (eval): 62284.05859375
# Epoch 89 error (train): 61970.88671875
# Epoch 89 error (eval): 62283.37109375
# Epoch 90 error (train): 61933.4765625
# Epoch 90 error (eval): 62218.5546875
# Epoch 91 error (train): 61925.4140625
# Epoch 91 error (eval): 62267.69140625
# Epoch 92 error (train): 61918.23828125
# Epoch 92 error (eval): 62224.6484375
# Epoch 93 error (train): 61863.78515625
# Epoch 93 error (eval): 62210.921875
# Epoch 94 error (train): 61853.140625
# Epoch 94 error (eval): 62223.1953125
# Epoch 95 error (train): 61827.85546875
# Epoch 95 error (eval): 62196.58984375
# Epoch 96 error (train): 61797.984375
# Epoch 96 error (eval): 62173.16796875
# Epoch 97 error (train): 61789.91796875
# Epoch 97 error (eval): 62159.0546875
# Epoch 98 error (train): 61761.48046875
# Epoch 98 error (eval): 62160.70703125
# Epoch 99 error (train): 61747.34765625
# Epoch 99 error (eval): 62151.875
#
# Regressor error: 61747.34765625
#
#
# Saved model in assets/relu-1-5-lr-0.0001-epch-100.pickle
#
# Completed relu-1-5!
# Epoch 0 error (train): 116636.9765625
# Epoch 0 error (eval): 115294.484375
# Epoch 1 error (train): 116341.296875
# Epoch 1 error (eval): 115016.0859375
# Epoch 2 error (train): 116090.2109375
# Epoch 2 error (eval): 114782.0
# Epoch 3 error (train): 115872.03125
# Epoch 3 error (eval): 114580.90625
# Epoch 4 error (train): 115676.34375
# Epoch 4 error (eval): 114400.875
# Epoch 5 error (train): 115496.59375
# Epoch 5 error (eval): 114236.75
# Epoch 6 error (train): 115328.359375
# Epoch 6 error (eval): 114083.46875
# Epoch 7 error (train): 115165.984375
# Epoch 7 error (eval): 113936.5625
# Epoch 8 error (train): 115008.078125
# Epoch 8 error (eval): 113793.0234375
# Epoch 9 error (train): 114853.5
# Epoch 9 error (eval): 113651.8828125
# Epoch 10 error (train): 114700.640625
# Epoch 10 error (eval): 113511.9609375
# Epoch 11 error (train): 114546.7265625
# Epoch 11 error (eval): 113369.734375
# Epoch 12 error (train): 114391.703125
# Epoch 12 error (eval): 113225.359375
# Epoch 13 error (train): 114233.3984375
# Epoch 13 error (eval): 113076.9296875
# Epoch 14 error (train): 114071.2109375
# Epoch 14 error (eval): 112923.0703125
# Epoch 15 error (train): 113905.703125
# Epoch 15 error (eval): 112766.3984375
# Epoch 16 error (train): 113738.28125
# Epoch 16 error (eval): 112607.0625
# Epoch 17 error (train): 113566.3984375
# Epoch 17 error (eval): 112442.4375
# Epoch 18 error (train): 113388.65625
# Epoch 18 error (eval): 112271.6796875
# Epoch 19 error (train): 113203.9453125
# Epoch 19 error (eval): 112092.6328125
# Epoch 20 error (train): 113013.375
# Epoch 20 error (eval): 111905.21875
# Epoch 21 error (train): 112812.8671875
# Epoch 21 error (eval): 111708.1015625
# Epoch 22 error (train): 112601.8671875
# Epoch 22 error (eval): 111500.5
# Epoch 23 error (train): 112380.625
# Epoch 23 error (eval): 111284.171875
# Epoch 24 error (train): 112149.3828125
# Epoch 24 error (eval): 111058.5703125
# Epoch 25 error (train): 111907.6171875
# Epoch 25 error (eval): 110822.2265625
# Epoch 26 error (train): 111652.2265625
# Epoch 26 error (eval): 110573.015625
# Epoch 27 error (train): 111379.375
# Epoch 27 error (eval): 110307.4140625
# Epoch 28 error (train): 111090.0625
# Epoch 28 error (eval): 110026.28125
# Epoch 29 error (train): 110784.5390625
# Epoch 29 error (eval): 109729.375
# Epoch 30 error (train): 110462.1015625
# Epoch 30 error (eval): 109414.5546875
# Epoch 31 error (train): 110121.84375
# Epoch 31 error (eval): 109080.5703125
# Epoch 32 error (train): 109761.359375
# Epoch 32 error (eval): 108725.0546875
# Epoch 33 error (train): 109380.5390625
# Epoch 33 error (eval): 108347.703125
# Epoch 34 error (train): 108975.765625
# Epoch 34 error (eval): 107947.1953125
# Epoch 35 error (train): 108544.3984375
# Epoch 35 error (eval): 107522.4375
# Epoch 36 error (train): 108088.3203125
# Epoch 36 error (eval): 107070.0234375
# Epoch 37 error (train): 107602.640625
# Epoch 37 error (eval): 106588.3828125
# Epoch 38 error (train): 107088.015625
# Epoch 38 error (eval): 106077.703125
# Epoch 39 error (train): 106541.6953125
# Epoch 39 error (eval): 105537.203125
# Epoch 40 error (train): 105961.2890625
# Epoch 40 error (eval): 104963.984375
# Epoch 41 error (train): 105343.328125
# Epoch 41 error (eval): 104353.2890625
# Epoch 42 error (train): 104689.21875
# Epoch 42 error (eval): 103708.6171875
# Epoch 43 error (train): 103993.625
# Epoch 43 error (eval): 103023.1484375
# Epoch 44 error (train): 103257.1640625
# Epoch 44 error (eval): 102298.4921875
# Epoch 45 error (train): 102475.3359375
# Epoch 45 error (eval): 101532.375
# Epoch 46 error (train): 101646.6328125
# Epoch 46 error (eval): 100720.03125
# Epoch 47 error (train): 100768.90625
# Epoch 47 error (eval): 99862.8046875
# Epoch 48 error (train): 99843.25
# Epoch 48 error (eval): 98960.7890625
# Epoch 49 error (train): 98872.0703125
# Epoch 49 error (eval): 98013.75
# Epoch 50 error (train): 97860.6328125
# Epoch 50 error (eval): 97024.578125
# Epoch 51 error (train): 96809.34375
# Epoch 51 error (eval): 95996.0390625
# Epoch 52 error (train): 95709.828125
# Epoch 52 error (eval): 94926.265625
# Epoch 53 error (train): 94576.2734375
# Epoch 53 error (eval): 93825.0703125
# Epoch 54 error (train): 93410.1640625
# Epoch 54 error (eval): 92695.109375
# Epoch 55 error (train): 92224.875
# Epoch 55 error (eval): 91545.390625
# Epoch 56 error (train): 91027.3125
# Epoch 56 error (eval): 90382.53125
# Epoch 57 error (train): 89815.3671875
# Epoch 57 error (eval): 89206.78125
# Epoch 58 error (train): 88602.9140625
# Epoch 58 error (eval): 88033.75
# Epoch 59 error (train): 87401.3046875
# Epoch 59 error (eval): 86872.546875
# Epoch 60 error (train): 86219.8359375
# Epoch 60 error (eval): 85729.484375
# Epoch 61 error (train): 85064.53125
# Epoch 61 error (eval): 84609.765625
# Epoch 62 error (train): 83941.3984375
# Epoch 62 error (eval): 83519.765625
# Epoch 63 error (train): 82860.1875
# Epoch 63 error (eval): 82468.859375
# Epoch 64 error (train): 81828.3046875
# Epoch 64 error (eval): 81466.25
# Epoch 65 error (train): 80855.5
# Epoch 65 error (eval): 80519.5390625

# %%
# from torch.nn import Sequential, Linear, ReLU

# display_loss_history(*train_regressor(
#     Sequential(
#         Linear(13, 1000),
#         ReLU(),
#         Linear(1000, 500),
#         ReLU(),
#         Linear(500, 500),
#         ReLU(),
#         Linear(500, 200),
#         ReLU(),
#         Linear(200, 1),
#     ),
#     model_name='relu1000x500x500x200',
#     nb_epochs=100,
# ))
# from torch.nn import Sequential, Linear, SiLU

# display_loss_history(*train_regressor(
#     Sequential(
#         Linear(13, 1000),
#         SiLU(),
#         Linear(1000, 500),
#         SiLU(),
#         Linear(500, 500),
#         SiLU(),
#         Linear(500, 200),
#         SiLU(),
#         Linear(200, 1),
#     ),
#     model_name='silu1000x500x500x200',
#     nb_epochs=100,
# ))
# Out:
# Epoch 0 error (train): 0.22046521306037903
# Epoch 0 error (eval): 0.22405286133289337
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 3
#       1 from torch.nn import Sequential, Linear, ReLU
# ----> 3 display_loss_history(*train_regressor(
#       4     Sequential(
#       5         Linear(13, 1000),
#       6         ReLU(),
#       7         Linear(1000, 500),
#       8         ReLU(),
#       9         Linear(500, 500),
#      10         ReLU(),
#      11         Linear(500, 200),
#      12         ReLU(),
#      13         Linear(200, 1),
#      14     ),
#      15     model_name='relu1000x500x500x200',
#      16     nb_epochs=100,
#      17 ))
#
# Cell In [2], line 25, in train_regressor(model, model_name, nb_epochs, learning_rate)
#      20 # Training
#      21 # This example trains on the whole available dataset.
#      22 # You probably want to separate some held-out data
#      23 # to make sure the model isn't overfitting
#      24 regressor = Regressor(x_train, model=model, nb_epoch=nb_epochs, batch_size=32, learning_rate=learning_rate)
# ---> 25 regressor.fit(x_train, y_train, x_eval=x_eval, y_eval=y_eval)
#      27 # Error
#      28 error = regressor.score(x_train, y_train)
#
# File /workspaces/CW2/part2_house_value_regression.py:210, in Regressor.fit(self, x, y, x_eval, y_eval)
#     207 # Compute loss
#     208 # Compute gradient of loss via backwards pass
#     209 loss = self.loss_fn(outputs, target_batch)
# --> 210 loss.backward()
#     212 # Change the weights via gradient decent
#     213 optimiser.step()
#
# File ~/.local/lib/python3.10/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
